# %% [markdown]
# <a href="https://colab.research.google.com/github/MaximilianoCalleros/Probabilidad-y-estad-stica/blob/Unidad1/PRO_U1_practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadística
# ##Facilitador: Jose Gabriel Rodríguez Rivas
# ##Alumno: Maximiliano Calleros

# %%
from statistics import *

# %%
#Lista de calificaciones de probabilidad y estadística
GrupoA = [70,70,65,90,100,95,45,80,73,20,100,96]
print(GrupoA)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
#La función type me transmite el tipo de dato
type(GrupoA)
# Out:
# list

# %%
#Sacar el promedio con una fórmula
Promedio=sum(GrupoA) / len(GrupoA)
print(Promedio)
# Out:
# 75.33333333333333

# %%
#Sacar promedio con una función
Promedio2=mean(GrupoA)
print(Promedio2)
# Out:
# 75.33333333333333

# %%
#Determinar el valor de la mediana
mediana=median(GrupoA)
print(mediana)
# Out:
# 76.5

# %%
#Tiempos100mts
tiempos=[15.10,17.20,14.69,13.37,22.15,18.71,19.15,20.65,15.10,17.20]
print(tiempos)
# Out:
# [15.1, 17.2, 14.69, 13.37, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
#Sacar la media de los valores con la función dentro del print
print("El tiempo promedio de los corredores es", mean(tiempos))
# Out:
# El tiempo promedio de los corredores es 17.332

# %%
#Sacando la mediana de los tiempos con la función median
mediana=median(tiempos)
print("La mediana de los tiempos de los corredores es =>", mediana)
# Out:
# La mediana de los tiempos de los corredores es => 17.2

# %%
#Sacando la moda de los tiempos con la función mode
moda=mode(tiempos)
print("La moda de los tiempos es =>", moda)
# Out:
# La moda de los tiempos es => 15.1

# %%
#Sacando varias medias con la función multimode
multimodas=multimode(tiempos)
print("Las modas de los tiempos son =>", multimodas)
# Out:
# Las modas de los tiempos son => [15.1, 17.2]

# %% [markdown]
# ##Ejemplo 3. Histograma de 2 grupos
#
# 1. En este ejemplo generamos 100 numeros aleatorios reales que representa la producción diaria de 100 telares (medidas en metros).
# 2. Generar otera lista con la producción de 100 telares para una segunda fabrica.
# 3. Con esta lista de valores se pretende determinar las medidas de tendencia central, la media, la moda, la mdeiana, la desviación estandar.
# 4. Graficar un histograma para cada fabrica.

# %%
#Libreria para generar valores aleatorios
import random

# %%
fabrica1=[]
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [58.58, 57.65, 76.8, 65.46, 71.92, 53.14, 84.83, 83.47, 68.11, 88.71, 65.61, 57.69, 96.13, 71.46, 92.56, 69.62, 87.72, 65.5, 84.16, 59.6, 74.93, 55.66, 93.74, 51.23, 98.13, 84.74, 53.66, 67.24, 83.79, 84.54, 72.39, 57.26, 86.18, 76.95, 93.87, 56.09, 88.19, 53.17, 78.21, 70.7, 99.6, 63.1, 52.84, 94.24, 78.21, 65.6, 67.33, 80.39, 97.31, 70.73, 73.94, 65.23, 74.09, 95.91, 91.79, 59.71, 95.73, 76.13, 96.47, 91.4, 50.27, 57.28, 67.5, 63.34, 99.4, 94.93, 91.27, 82.12, 90.58, 67.71, 92.54, 90.95, 82.5, 66.21, 77.28, 55.42, 64.2, 55.3, 54.52, 51.08, 68.58, 72.23, 80.33, 88.77, 80.38, 59.07, 52.37, 88.88, 64.48, 91.11, 89.94, 62.3, 66.32, 95.85, 60.6, 60.8, 66.87, 99.25, 62.06, 69.21]

# %%
fabrica2=[]
for i in range(100):
  numero_aleatorio2 = round(random.uniform(50,100),2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [66.94, 86.38, 55.53, 67.56, 53.95, 63.2, 74.55, 64.44, 98.99, 58.31, 66.62, 96.73, 58.49, 63.82, 65.05, 54.25, 58.89, 78.84, 77.71, 99.31, 64.03, 59.83, 67.01, 54.81, 52.82, 98.22, 53.32, 95.73, 69.23, 89.18, 80.84, 91.63, 64.2, 59.46, 77.73, 68.88, 67.21, 73.01, 82.04, 56.81, 91.21, 56.9, 57.8, 61.83, 55.4, 60.67, 97.34, 92.88, 78.23, 92.15, 84.92, 50.78, 56.99, 91.94, 90.33, 82.95, 95.51, 88.22, 53.28, 74.82, 73.32, 89.52, 92.18, 90.65, 93.14, 96.66, 54.7, 53.39, 87.86, 72.24, 96.96, 74.4, 65.68, 54.68, 94.07, 79.62, 66.1, 78.46, 92.36, 86.8, 63.63, 53.7, 95.93, 53.26, 99.07, 60.05, 77.46, 71.21, 69.38, 82.81, 63.01, 90.73, 61.78, 54.35, 71.06, 65.64, 68.22, 95.83, 92.93, 85.44]

# %%
#Libreria de pyton para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
media=mean(fabrica1)
mediana=median(fabrica1)
moda=mode(fabrica1)
print("Valores de la fabrica 1")
print("La media=", media)
print("La mediana es =", mediana)
print("La moda es =", moda)
# Out:
# Valores de la fabrica 1
# La media= 74.6294
# La mediana es = 72.31
# La moda es = 78.21

# %%
media=mean(fabrica2)
mediana=median(fabrica2)
moda=mode(fabrica2)
print("Valores de la fabrica 2")
print("La media=", media)
print("La mediana es =", mediana)
print("La moda es =", moda)
# Out:
# Valores de la fabrica 2
# La media= 74.1798
# La mediana es = 71.725
# La moda es = 66.94

# %%
# Generar 2 subplot de 1 renglon pr 2 columnas para desplegar los 2 histogramas, uno al lado del otro
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

# %%
# Generar 2 subplot de 1 renglon pr 2 columnas para desplegar los 2 histogramas, uno al lado del otro
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
#Valor minimo, maximo, rango
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)

# %%
plt.hist(fabrica1, bins=20,alpha=0.2, color='b',edgecolor="black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)

plt.hist(fabrica2, bins=10,alpha=0.2, color='b',edgecolor="black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ## Maximio, minimo y rango

# %%
maximo = max(fabrica1)
minimo = min(fabrica1)
rango = maximo - minimo
madia = mean(fabrica1)
mediana = median(fabrica1)
moda = mode(fabrica1)

print("Estadistica descriptiva de la fabrica 1 \n", "media= ", media, " \n mediana= ",mediana, " \n moda= ",moda,"\n maximo=",maximo,"\n minimo=",minimo,"\n rango=",rango)
# Out:
# Estadistica descriptiva de la fabrica 1
#  media=  74.1798
#  mediana=  72.31
#  moda=  78.21
#  maximo= 99.6
#  minimo= 50.27
#  rango= 49.32999999999999

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo - minimo
madia2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Estadistica descriptiva de la fabrica 2 \n", "media= ", media2, " \n mediana= ",mediana2, " \n moda= ",moda2,"\n maximo=",maximo2,"\n minimo=",minimo2,"\n rango=",rango2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  media=  74.1798
#  mediana=  71.725
#  moda=  66.94
#  maximo= 99.31
#  minimo= 50.78
#  rango= 49.32999999999999

# %% [markdown]
# ##Dispersión de los datos

# %%
desviacion_estandar_fabrica1= stdev(fabrica1)
print("la desvicion estandar de la fabrica 1 es = ",desviacion_estandar_fabrica1)
# Out:
# la desvicion estandar de la fabrica 1 es =  14.686621399124174

# %%
desviacion_estandar_fabrica2= stdev(fabrica2)
print("la desvicion estandar de la fabrica 2 es = ",desviacion_estandar_fabrica2)
# Out:
# la desvicion estandar de la fabrica 2 es =  15.225815198026162

# %%
plt.figure(figsize = (10,8))
plt.hist(fabrica1, bins=10,alpha=0.2, color='b',edgecolor="black")
plt.axvline(media, color='b', linestyle='dashed', linewidth=2, label=f'Media= {media:.2f}')
plt.axvline(mediana, color='r', linestyle='dashed', linewidth=2, label=f'Mediana= {mediana:.2f}')
plt.axvline(moda, color='y', linestyle='dashed', linewidth=2, label=f'Moda= {moda:.2f}')
plt.axvline(media - desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar= {desviacion_estandar_fabrica1:.2f}')
plt.axvline(media + desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,8))
plt.hist(fabrica2, bins=10,alpha=0.2, color='b',edgecolor="black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media= {media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana= {mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda= {moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estándar= {desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %% [markdown]
# ##Tablas de frecuencia

# %%
# generamos una lista vacia que repsresenta un grupo de personas
edades=[]
for i in range(100):
  numero_aleaotrio=random.randint(18,70)
  edades.append(numero_aleaotrio)
print (edades)
# Out:
# [21, 53, 38, 18, 58, 22, 38, 29, 53, 34, 33, 49, 59, 68, 58, 44, 19, 35, 60, 59, 31, 39, 69, 53, 58, 47, 60, 60, 38, 64, 40, 32, 30, 34, 37, 69, 30, 56, 59, 59, 49, 23, 36, 39, 27, 30, 22, 66, 23, 70, 51, 65, 22, 68, 55, 29, 69, 23, 44, 33, 67, 48, 70, 48, 24, 51, 33, 56, 66, 56, 53, 55, 49, 25, 59, 67, 35, 36, 37, 48, 28, 56, 40, 28, 64, 68, 28, 41, 45, 49, 68, 39, 33, 43, 33, 39, 65, 32, 51, 52]

# %%
import pandas as pd
df_edades = pd.DataFrame(edades, columns=["Edad"])
df_edades
# Out:
#     Edad
# 0     21
# 1     53
# 2     38
# 3     18
# 4     58
# ..   ...
# 95    39
# 96    65
# 97    32
# 98    51
# 99    52
#
# [100 rows x 1 columns]

# %%
#Calcular la tabla de distribucion de frecuencias
tabla_frecuencias=df_edades["Edad"].value_counts().reset_index()
tabla_frecuencias.columns=["Edad", "Frecuencia"]
tabla_frecuencias=tabla_frecuencias.sort_values(by="Edad")
tabla_frecuencias
# Out:
#     Edad  Frecuencia
# 41    18           1
# 40    19           1
# 36    21           1
# 16    22           3
# 10    23           3
# 34    24           1
# 33    25           1
# 37    27           1
# 12    28           3
# 26    29           2
# 11    30           3
# 39    31           1
# 25    32           2
# 0     33           5
# 28    34           2
# 24    35           2
# 23    36           2
# 17    37           2
# 15    38           3
# 6     39           4
# 30    40           2
# 35    41           1
# 32    43           1
# 29    44           2
# 31    45           1
# 38    47           1
# 13    48           3
# 4     49           4
# 9     51           3
# 42    52           1
# 3     53           4
# 19    55           2
# 2     56           4
# 14    58           3
# 1     59           5
# 8     60           3
# 27    64           2
# 20    65           2
# 22    66           2
# 18    67           2
# 5     68           4
# 7     69           3
# 21    70           2

# %%
tabla_frecuencias["Frec. Relativa"]= tabla_frecuencias["Frecuencia"]/100

# %%
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa
# 41    18           1            0.01
# 40    19           1            0.01
# 36    21           1            0.01
# 16    22           3            0.03
# 10    23           3            0.03
# 34    24           1            0.01
# 33    25           1            0.01
# 37    27           1            0.01
# 12    28           3            0.03
# 26    29           2            0.02
# 11    30           3            0.03
# 39    31           1            0.01
# 25    32           2            0.02
# 0     33           5            0.05
# 28    34           2            0.02
# 24    35           2            0.02
# 23    36           2            0.02
# 17    37           2            0.02
# 15    38           3            0.03
# 6     39           4            0.04
# 30    40           2            0.02
# 35    41           1            0.01
# 32    43           1            0.01
# 29    44           2            0.02
# 31    45           1            0.01
# 38    47           1            0.01
# 13    48           3            0.03
# 4     49           4            0.04
# 9     51           3            0.03
# 42    52           1            0.01
# 3     53           4            0.04
# 19    55           2            0.02
# 2     56           4            0.04
# 14    58           3            0.03
# 1     59           5            0.05
# 8     60           3            0.03
# 27    64           2            0.02
# 20    65           2            0.02
# 22    66           2            0.02
# 18    67           2            0.02
# 5     68           4            0.04
# 7     69           3            0.03
# 21    70           2            0.02

# %%
#Calcular la frecuenica porcental
tabla_frecuencias["Frec. porcentual"]=tabla_frecuencias["Frecuencia"]/100*100

# %%
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. porcentual
# 41    18           1            0.01               1.0
# 40    19           1            0.01               1.0
# 36    21           1            0.01               1.0
# 16    22           3            0.03               3.0
# 10    23           3            0.03               3.0
# 34    24           1            0.01               1.0
# 33    25           1            0.01               1.0
# 37    27           1            0.01               1.0
# 12    28           3            0.03               3.0
# 26    29           2            0.02               2.0
# 11    30           3            0.03               3.0
# 39    31           1            0.01               1.0
# 25    32           2            0.02               2.0
# 0     33           5            0.05               5.0
# 28    34           2            0.02               2.0
# 24    35           2            0.02               2.0
# 23    36           2            0.02               2.0
# 17    37           2            0.02               2.0
# 15    38           3            0.03               3.0
# 6     39           4            0.04               4.0
# 30    40           2            0.02               2.0
# 35    41           1            0.01               1.0
# 32    43           1            0.01               1.0
# 29    44           2            0.02               2.0
# 31    45           1            0.01               1.0
# 38    47           1            0.01               1.0
# 13    48           3            0.03               3.0
# 4     49           4            0.04               4.0
# 9     51           3            0.03               3.0
# 42    52           1            0.01               1.0
# 3     53           4            0.04               4.0
# 19    55           2            0.02               2.0
# 2     56           4            0.04               4.0
# 14    58           3            0.03               3.0
# 1     59           5            0.05               5.0
# 8     60           3            0.03               3.0
# 27    64           2            0.02               2.0
# 20    65           2            0.02               2.0
# 22    66           2            0.02               2.0
# 18    67           2            0.02               2.0
# 5     68           4            0.04               4.0
# 7     69           3            0.03               3.0
# 21    70           2            0.02               2.0

# %%
#Calcular la frecuencia acumulada
#Agregamos una nueva columna con el calculo
tabla_frecuencias["Frec. acumulada"]=tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. porcentual  Frec. acumulada
# 41    18           1            0.01               1.0                1
# 40    19           1            0.01               1.0                2
# 36    21           1            0.01               1.0                3
# 16    22           3            0.03               3.0                6
# 10    23           3            0.03               3.0                9
# 34    24           1            0.01               1.0               10
# 33    25           1            0.01               1.0               11
# 37    27           1            0.01               1.0               12
# 12    28           3            0.03               3.0               15
# 26    29           2            0.02               2.0               17
# 11    30           3            0.03               3.0               20
# 39    31           1            0.01               1.0               21
# 25    32           2            0.02               2.0               23
# 0     33           5            0.05               5.0               28
# 28    34           2            0.02               2.0               30
# 24    35           2            0.02               2.0               32
# 23    36           2            0.02               2.0               34
# 17    37           2            0.02               2.0               36
# 15    38           3            0.03               3.0               39
# 6     39           4            0.04               4.0               43
# 30    40           2            0.02               2.0               45
# 35    41           1            0.01               1.0               46
# 32    43           1            0.01               1.0               47
# 29    44           2            0.02               2.0               49
# 31    45           1            0.01               1.0               50
# 38    47           1            0.01               1.0               51
# 13    48           3            0.03               3.0               54
# 4     49           4            0.04               4.0               58
# 9     51           3            0.03               3.0               61
# 42    52           1            0.01               1.0               62
# 3     53           4            0.04               4.0               66
# 19    55           2            0.02               2.0               68
# 2     56           4            0.04               4.0               72
# 14    58           3            0.03               3.0               75
# 1     59           5            0.05               5.0               80
# 8     60           3            0.03               3.0               83
# 27    64           2            0.02               2.0               85
# 20    65           2            0.02               2.0               87
# 22    66           2            0.02               2.0               89
# 18    67           2            0.02               2.0               91
# 5     68           4            0.04               4.0               95
# 7     69           3            0.03               3.0               98
# 21    70           2            0.02               2.0              100

# %% [markdown]
# ##Regla de sturges

# %%
#Libreria de funciones matematias
import math

# %%
print(edades)
# Out:
# [21, 53, 38, 18, 58, 22, 38, 29, 53, 34, 33, 49, 59, 68, 58, 44, 19, 35, 60, 59, 31, 39, 69, 53, 58, 47, 60, 60, 38, 64, 40, 32, 30, 34, 37, 69, 30, 56, 59, 59, 49, 23, 36, 39, 27, 30, 22, 66, 23, 70, 51, 65, 22, 68, 55, 29, 69, 23, 44, 33, 67, 48, 70, 48, 24, 51, 33, 56, 66, 56, 53, 55, 49, 25, 59, 67, 35, 36, 37, 48, 28, 56, 40, 28, 64, 68, 28, 41, 45, 49, 68, 39, 33, 43, 33, 39, 65, 32, 51, 52]

# %%
plt.hist(edades, alpha=0.5,rwidth=.95)
plt.title("Histograma de edades basado en valores estandar de matplotlib")
plt.xlabel("Edades")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
df_edades_sturges= pd.DataFrame({"Edad":edades})
df_edades_sturges
# Out:
#     Edad
# 0     21
# 1     53
# 2     38
# 3     18
# 4     58
# ..   ...
# 95    39
# 96    65
# 97    32
# 98    51
# 99    52
#
# [100 rows x 1 columns]

# %%
#Calcular el numero de interlvalos o clases utilizando la regla de sturges
n=len(edades)
k=int(1+math.log2(n))
print("Valor de n= ",n,"\nValor de k o numero de intervalso o clases= ",k)
# Out:
# Valor de n=  100
# Valor de k o numero de intervalso o clases=  7

# %%
tabla_frec_sturges=pd.cut(df_edades_sturges["Edad"],bins=k).value_counts().reset_index()

# %%
tabla_frec_sturges
# Out:
#               index  Edad
# 0  (32.857, 40.286]    22
# 1  (47.714, 55.143]    17
# 2    (62.571, 70.0]    17
# 3  (55.143, 62.571]    15
# 4  (25.429, 32.857]    12
# 5  (17.948, 25.429]    11
# 6  (40.286, 47.714]     6

# %%
tabla_frec_sturges.columns=["Clase","Frecuencia"]
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 0  (32.857, 40.286]          22
# 1  (47.714, 55.143]          17
# 2    (62.571, 70.0]          17
# 3  (55.143, 62.571]          15
# 4  (25.429, 32.857]          12
# 5  (17.948, 25.429]          11
# 6  (40.286, 47.714]           6

# %%
#Ordenar la tabla de frecuencia por la clase o el intervalo
tabla_frec_sturges=tabla_frec_sturges.sort_values(by="Clase")
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 5  (17.948, 25.429]          11
# 4  (25.429, 32.857]          12
# 0  (32.857, 40.286]          22
# 6  (40.286, 47.714]           6
# 1  (47.714, 55.143]          17
# 3  (55.143, 62.571]          15
# 2    (62.571, 70.0]          17

# %%
tabla_frec_sturges["Frec. relativa"]=tabla_frec_sturges["Frecuencia"]/n
tabla_frec_sturges["Frec. porcentual"]=tabla_frec_sturges["Frecuencia"]/n*100
tabla_frec_sturges["Frec. acumulada"]=tabla_frec_sturges["Frecuencia"].cumsum()

# %%
tabla_frec_sturges
# Out:
#               Clase  Frecuencia  Frec. relativa  Frec. porcentual  \
# 5  (17.948, 25.429]          11            0.11              11.0
# 4  (25.429, 32.857]          12            0.12              12.0
# 0  (32.857, 40.286]          22            0.22              22.0
# 6  (40.286, 47.714]           6            0.06               6.0
# 1  (47.714, 55.143]          17            0.17              17.0
# 3  (55.143, 62.571]          15            0.15              15.0
# 2    (62.571, 70.0]          17            0.17              17.0
#
#    Frec. acumulada
# 5               11
# 4               23
# 0               45
# 6               51
# 1               68
# 3               83
# 2              100

# %%
plt.hist(df_edades_sturges["Edad"],bins=k,alpha=.5,rwidth=.95)
plt.title("Histograma de edades basado en la regla de sturges")
plt.xlabel("Edades")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')
